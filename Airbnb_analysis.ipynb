# %% [markdown]
# Airbnb New york city dataset analysis practice notebook

# %%
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
#sns.set_theme(style='darkgrid')

# %% [markdown]
# Load the data from the csv file

# %%
df = pd.read_csv(r'AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df = df[pd.notnull(df['name'])]
df = df[pd.notnull(df['host_name'])]

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
print("Maximum price: ",df['price'].max())
print("Minimum price: ",df['price'].min())
print("Median price: ",df['price'].mean())
# Out:
# Maximum price:  10000
# Minimum price:  0
# Median price:  152.74030864955586

# %%
df.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# Visualization

# %%
v_df = df.copy()

# %%
v_df1 = v_df.drop(columns = ['name','host_name','neighbourhood_group','neighbourhood','room_type','last_review'])
fig, ax = plt.subplots(figsize=(10,8))
ax = sns.heatmap(v_df1.corr(),annot=True)

# %%
v_df_price = v_df['price']

#plotting criterias longitude and latitude

sns.relplot(x=v_df['longitude'],y=v_df['latitude'],data=v_df_price)

# %%
NYC_map = plt.imread('New_York_City_.png',0)

plt.figure(figsize=(10,8))

plt.imshow(NYC_map, zorder=0, extent=[-74.258, -73.7, 40.49,40.92])

ax = plt.gca()

plt.scatter(v_df['longitude'], v_df['latitude'], cmap=plt.get_cmap('brg'),colorbar=True, alpha=0.2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9098aa1ef733> in <module>
#       7 ax = plt.gca()
#       8
# ----> 9 plt.scatter(v_df['longitude'], v_df['latitude'], cmap=plt.get_cmap('brg'),colorbar=True, alpha=0.2)
#
# D:\anaconda\envs\tfenv\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2877         verts=verts, edgecolors=edgecolors,
#    2878         plotnonfinite=plotnonfinite,
# -> 2879         **({"data": data} if data is not None else {}), **kwargs)
#    2880     sci(__ret)
#    2881     return __ret
#
# D:\anaconda\envs\tfenv\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...
